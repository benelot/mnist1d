# %% [markdown]
# # Quickstart for MNIST-1D
# Sam Greydanus | 2020
#
# This notebook shows how to build the MNIST-1D dataset and train some baselines*.
#
# _* If you're running this in Colab, it's best to use a GPU runtime._

# %%
# Run this if you're in a Colab
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import numpy as np
import torch
import random
import matplotlib.pyplot as plt

import sys ; sys.path.append('..'); sys.path.append('.')  # useful if you're running locally
import mnist1d

from mnist1d.data import get_templates, get_dataset_args, get_dataset
from train import get_model_args, train_model
from models import ConvBase, GRUBase, MLPBase, LinearBase
from mnist1d.utils import set_seed, plot_signals, ObjectView, from_pickle

# Try attaching to GPU
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %% [markdown]
# ## Step 1: Visualize templates
# To construct MNIST-1D, we start with ten 1D signals, each of which resembles a digit in the range 0-9.

# %%
templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_signals(x, t, labels=y, ratio=1.33, dark_mode=True)
# Out:
# Templates for the MNIST-1D dataset:

# %%
fig = plot_signals(x, t, labels=y, ratio=1.33, dark_mode=False)

# %% [markdown]
# ## Step 2: Transform
#
# Now we are going to transform these signals in such a way that they become difficult to classify. Nonlinear representations and good spatial priors will become very important in order to classify them.

# %%
get_dataset_args(as_dict=True)
# Out:
# {'num_samples': 5000,
#  'train_split': 0.8,
#  'template_len': 12,
#  'padding': [36, 60],
#  'scale_coeff': 0.4,
#  'max_translation': 48,
#  'corr_noise_scale': 0.25,
#  'iid_noise_scale': 0.02,
#  'shear_scale': 0.75,
#  'shuffle_seq': False,
#  'final_seq_length': 40,
#  'seed': 42,
#  'url': 'https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl'}

# %%
arg_dict = get_dataset_args(as_dict=True)

arg_dict['padding'] = [36, 60]
arg_dict['max_translation'] = 48
arg_dict['scale_coeff'] = 0
arg_dict['corr_noise_scale'] = 0
arg_dict['iid_noise_scale'] = 0
arg_dict['shear_scale'] = 0
args = ObjectView(arg_dict)

x = templates['x']
t = templates['t']
y = templates['y']
set_seed(args.seed)
fig = plot_signals(x, t, labels=y, args=args, ratio=2.2, do_transform=True)

# %%
args = get_dataset_args()

x = templates['x']
t = templates['t']
y = templates['y']
set_seed(args.seed)
fig = plot_signals(x, t, labels=y, args=args, ratio=2.2, do_transform=True)

# %% [markdown]
# ## Step 3: Make a dataset
# Next we are going to construct a classification dataset, analogous to MNIST but much smaller, using these signals. Note that the dataset gets saved as a small pickle file, so you don't have to build it from scratch every time.

# %%
args = get_dataset_args()
data = get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
args = get_dataset_args()
data = get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
print("Number of classes: {}".format(len(data['templates']['y'])))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40
# Number of classes: 10

# %% [markdown]
# ## Step 3b: Download the baseline dataset
# It's always possible that the open-source libraries that we used to synthesize this dataset will change. Even if they change slightly, the dataset one obtains from running the code above may change slightly, making it hard for you and I to compare results.
#
# If you want to use MNIST-1D as a baseline, we suggest that you load it using the pickle file provided in the repo. The dataset contained in that file will serve as the one-and-only, original MNIST1D dataset. The link is https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl. The `mnist1d.get_dataset` function loads this file when `download` is set to `True`:

# %%
args = get_dataset_args()
data = get_dataset(args, path='./mnist1d_data.pkl', download=True) # This is the default setting
# Out:
# File already exists. Skipping download.
# Successfully loaded data from ./mnist1d_data.pkl

# %% [markdown]
# ## Step 4: Run baselines*
#
# We'll see that:
# * Nonlinear classifiers do better than linear classifiers.
# * Classifiers with transformation invariance and local connectivity (CNNs) do better than ones without these properties (MLPs).
#
# An additional note:
# * Humans do just a bit better than the other baselines (human performance is 95.8% on 500 test set examples). This suggests that shortcut learning and memorization don't help much.
#
# _*You may see slightly different numbers than the ones from the default run. This is due to the fact that you are using a GPU instead of CPU: PyTorch's random seeding function ``torch.cuda.manual_seed_all(seed)`` causes this difference. Your results will be reproducible between GPUs._

# %%
get_model_args(as_dict=True)
# Out:
# {'input_size': 40,
#  'output_size': 10,
#  'hidden_size': 256,
#  'learning_rate': 0.01,
#  'weight_decay': 0,
#  'batch_size': 100,
#  'total_steps': 8000,
#  'print_every': 1000,
#  'eval_every': 250,
#  'checkpoint_every': 1000,
#  'device': 'cpu',
#  'seed': 42}

# %%
# Note: if you run on a GPU, the walltimes will be _much_ lower
args = get_model_args()
args.total_steps = 20000
args.device = DEVICE

set_seed(args.seed)
model = ConvBase(output_size=args.output_size)
results_cnn = train_model(data, model, args)
print()

set_seed(args.seed)
model = GRUBase(input_size=1, output_size=args.output_size)
results_gru = train_model(data, model, args)
print()

set_seed(args.seed)
model = MLPBase(args.input_size, args.output_size)
results_mlp = train_model(data, model, args)
print()

set_seed(args.seed)
model = LinearBase(args.input_size, args.output_size)
results_lin = train_model(data, model, args)
print()
# Out:
# Initialized ConvBase model with 37785 parameters
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# step 1000, dt 2.53s, train_loss 3.141e-02, test_loss 2.531e-01, train_acc 99.0, test_acc 93.9
# 0.01
# 0.01
# 0.01
# 0.01
# step 2000, dt 2.41s, train_loss 1.555e-01, test_loss 3.304e-01, train_acc 98.2, test_acc 92.4
# 0.01
# 0.01
# 0.01
# 0.01
# step 3000, dt 2.42s, train_loss 1.127e-05, test_loss 2.167e-01, train_acc 100.0, test_acc 96.0
# 0.01
# 0.01
# 0.01
# 0.01
# step 4000, dt 2.42s, train_loss 4.670e-06, test_loss 2.338e-01, train_acc 100.0, test_acc 96.1
# 0.01
# 0.01
# 0.01
# 0.01
# step 5000, dt 2.40s, train_loss 2.403e-06, test_loss 2.463e-01, train_acc 100.0, test_acc 96.1
# 0.01
# 0.01
# 0.01
# 0.01
# step 6000, dt 2.42s, train_loss 1.304e-06, test_loss 2.569e-01, train_acc 100.0, test_acc 96.1
# 0.01
# 0.01
# 0.01
# 0.01
# step 7000, dt 2.41s, train_loss 7.033e-07, test_loss 2.661e-01, train_acc 100.0, test_acc 96.1
# 0.01
# 0.01
# Epoch    32: reducing learning rate of group 0 to 9.0000e-03.
# 0.009000000000000001
# 0.009000000000000001
# step 8000, dt 2.37s, train_loss 4.053e-07, test_loss 2.746e-01, train_acc 100.0, test_acc 96.3
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 9000, dt 2.42s, train_loss 2.432e-07, test_loss 2.820e-01, train_acc 100.0, test_acc 96.4
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 10000, dt 2.42s, train_loss 1.454e-07, test_loss 2.899e-01, train_acc 100.0, test_acc 96.4
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 11000, dt 2.41s, train_loss 8.583e-08, test_loss 2.984e-01, train_acc 100.0, test_acc 96.3
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 12000, dt 2.46s, train_loss 5.245e-08, test_loss 3.069e-01, train_acc 100.0, test_acc 96.2
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# Epoch    53: reducing learning rate of group 0 to 8.1000e-03.
# 0.008100000000000001
# step 13000, dt 2.45s, train_loss 2.980e-08, test_loss 3.155e-01, train_acc 100.0, test_acc 96.1
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 14000, dt 2.39s, train_loss 1.788e-08, test_loss 3.235e-01, train_acc 100.0, test_acc 96.1
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 15000, dt 2.35s, train_loss 1.073e-08, test_loss 3.318e-01, train_acc 100.0, test_acc 96.1
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 16000, dt 2.36s, train_loss 5.960e-09, test_loss 3.397e-01, train_acc 100.0, test_acc 96.2
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 17000, dt 2.41s, train_loss 3.576e-09, test_loss 3.471e-01, train_acc 100.0, test_acc 96.0
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 18000, dt 2.44s, train_loss 2.384e-09, test_loss 3.539e-01, train_acc 100.0, test_acc 96.1
# Epoch    74: reducing learning rate of group 0 to 7.2900e-03.
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 19000, dt 2.41s, train_loss 1.192e-09, test_loss 3.580e-01, train_acc 100.0, test_acc 96.0
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 20000, dt 2.41s, train_loss 0.000e+00, test_loss 3.605e-01, train_acc 100.0, test_acc 96.0
#
# Initialized GRUBase model with 5134 parameters
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# step 1000, dt 3.31s, train_loss 9.236e-02, test_loss 3.444e-01, train_acc 95.0, test_acc 88.0
# 0.01
# 0.01
# 0.01
# 0.01
# step 2000, dt 3.24s, train_loss 6.171e-02, test_loss 4.258e-01, train_acc 97.3, test_acc 88.3
# 0.01
# 0.01
# 0.01
# 0.01
# step 3000, dt 3.36s, train_loss 2.165e-02, test_loss 4.546e-01, train_acc 98.5, test_acc 89.7
# 0.01
# 0.01
# 0.01
# 0.01
# step 4000, dt 3.26s, train_loss 1.407e-02, test_loss 5.326e-01, train_acc 99.0, test_acc 88.1
# 0.01
# 0.01
# 0.01
# 0.01
# step 5000, dt 3.29s, train_loss 2.277e-02, test_loss 4.744e-01, train_acc 99.8, test_acc 90.1
# 0.01
# 0.01
# 0.01
# Epoch    25: reducing learning rate of group 0 to 9.0000e-03.
# 0.009000000000000001
# step 6000, dt 3.26s, train_loss 4.753e-03, test_loss 5.166e-01, train_acc 99.8, test_acc 90.6
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 7000, dt 3.24s, train_loss 2.660e-03, test_loss 5.459e-01, train_acc 99.8, test_acc 90.6
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 8000, dt 3.29s, train_loss 1.286e-03, test_loss 5.703e-01, train_acc 99.8, test_acc 90.7
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 9000, dt 3.26s, train_loss 6.517e-04, test_loss 5.909e-01, train_acc 100.0, test_acc 91.1
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 10000, dt 3.28s, train_loss 3.690e-04, test_loss 6.193e-01, train_acc 100.0, test_acc 90.9
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 11000, dt 3.30s, train_loss 2.276e-04, test_loss 6.537e-01, train_acc 100.0, test_acc 91.1
# Epoch    46: reducing learning rate of group 0 to 8.1000e-03.
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 12000, dt 3.29s, train_loss 1.470e-04, test_loss 6.903e-01, train_acc 100.0, test_acc 91.0
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 13000, dt 3.30s, train_loss 1.021e-04, test_loss 7.329e-01, train_acc 100.0, test_acc 90.7
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 14000, dt 3.28s, train_loss 1.307e-02, test_loss 8.072e-01, train_acc 97.8, test_acc 88.5
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 15000, dt 3.54s, train_loss 1.146e-04, test_loss 5.621e-01, train_acc 100.0, test_acc 92.0
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 16000, dt 3.26s, train_loss 9.763e-05, test_loss 5.752e-01, train_acc 100.0, test_acc 92.1
# 0.008100000000000001
# Epoch    67: reducing learning rate of group 0 to 7.2900e-03.
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 17000, dt 3.35s, train_loss 8.833e-05, test_loss 5.886e-01, train_acc 100.0, test_acc 92.2
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 18000, dt 3.41s, train_loss 7.845e-05, test_loss 6.032e-01, train_acc 100.0, test_acc 92.4
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 19000, dt 3.53s, train_loss 6.700e-05, test_loss 6.203e-01, train_acc 100.0, test_acc 92.1
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 20000, dt 3.38s, train_loss 5.528e-05, test_loss 6.397e-01, train_acc 100.0, test_acc 91.8
#
# Initialized MLPBase model with 15210 parameters
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# step 1000, dt 1.33s, train_loss 2.786e-01, test_loss 1.826e+00, train_acc 90.7, test_acc 60.6
# 0.01
# 0.01
# 0.01
# 0.01
# step 2000, dt 1.35s, train_loss 1.520e-01, test_loss 2.483e+00, train_acc 97.9, test_acc 64.8
# 0.01
# 0.01
# 0.01
# 0.01
# step 3000, dt 1.33s, train_loss 1.286e-01, test_loss 3.414e+00, train_acc 97.3, test_acc 64.0
# 0.01
# 0.01
# 0.01
# 0.01
# step 4000, dt 1.33s, train_loss 1.861e-04, test_loss 3.534e+00, train_acc 100.0, test_acc 64.4
# 0.01
# 0.01
# 0.01
# 0.01
# step 5000, dt 1.33s, train_loss 8.446e-05, test_loss 3.596e+00, train_acc 100.0, test_acc 64.4
# 0.01
# Epoch    23: reducing learning rate of group 0 to 9.0000e-03.
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 6000, dt 1.31s, train_loss 5.193e-05, test_loss 3.652e+00, train_acc 100.0, test_acc 64.8
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 7000, dt 1.31s, train_loss 3.386e-05, test_loss 3.711e+00, train_acc 100.0, test_acc 64.7
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 8000, dt 1.31s, train_loss 2.204e-05, test_loss 3.772e+00, train_acc 100.0, test_acc 65.1
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 9000, dt 1.30s, train_loss 1.410e-05, test_loss 3.848e+00, train_acc 100.0, test_acc 65.0
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 10000, dt 1.31s, train_loss 9.136e-06, test_loss 3.926e+00, train_acc 100.0, test_acc 65.0
# 0.009000000000000001
# 0.009000000000000001
# Epoch    44: reducing learning rate of group 0 to 8.1000e-03.
# 0.008100000000000001
# 0.008100000000000001
# step 11000, dt 1.28s, train_loss 5.978e-06, test_loss 4.008e+00, train_acc 100.0, test_acc 64.6
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 12000, dt 1.26s, train_loss 4.021e-06, test_loss 4.089e+00, train_acc 100.0, test_acc 64.6
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 13000, dt 1.30s, train_loss 2.631e-06, test_loss 4.176e+00, train_acc 100.0, test_acc 64.7
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 14000, dt 1.29s, train_loss 1.568e-06, test_loss 4.266e+00, train_acc 100.0, test_acc 64.8
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 15000, dt 1.31s, train_loss 9.739e-07, test_loss 4.366e+00, train_acc 100.0, test_acc 64.7
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# Epoch    65: reducing learning rate of group 0 to 7.2900e-03.
# 0.007290000000000001
# step 16000, dt 1.32s, train_loss 6.056e-07, test_loss 4.474e+00, train_acc 100.0, test_acc 65.1
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 17000, dt 1.31s, train_loss 3.850e-07, test_loss 4.575e+00, train_acc 100.0, test_acc 65.4
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 18000, dt 1.32s, train_loss 2.420e-07, test_loss 4.679e+00, train_acc 100.0, test_acc 65.4
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 19000, dt 1.32s, train_loss 1.442e-07, test_loss 4.790e+00, train_acc 100.0, test_acc 65.3
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 20000, dt 1.31s, train_loss 8.941e-08, test_loss 4.896e+00, train_acc 100.0, test_acc 65.2
#
# Initialized LinearBase model with 410 parameters
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# step 1000, dt 0.63s, train_loss 1.537e+00, test_loss 1.663e+00, train_acc 37.0, test_acc 32.4
# 0.01
# 0.01
# 0.01
# 0.01
# step 2000, dt 0.61s, train_loss 1.533e+00, test_loss 1.667e+00, train_acc 37.1, test_acc 32.0
# 0.01
# 0.01
# 0.01
# 0.01
# step 3000, dt 0.63s, train_loss 1.534e+00, test_loss 1.670e+00, train_acc 37.1, test_acc 31.6
# 0.01
# 0.01
# 0.01
# 0.01
# step 4000, dt 0.63s, train_loss 1.534e+00, test_loss 1.671e+00, train_acc 37.1, test_acc 31.3
# 0.01
# 0.01
# 0.01
# 0.01
# step 5000, dt 0.63s, train_loss 1.535e+00, test_loss 1.672e+00, train_acc 37.2, test_acc 31.7
# 0.01
# 0.01
# 0.01
# Epoch    25: reducing learning rate of group 0 to 9.0000e-03.
# 0.009000000000000001
# step 6000, dt 0.58s, train_loss 1.535e+00, test_loss 1.673e+00, train_acc 37.2, test_acc 31.7
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 7000, dt 0.60s, train_loss 1.533e+00, test_loss 1.671e+00, train_acc 37.4, test_acc 31.6
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 8000, dt 0.63s, train_loss 1.533e+00, test_loss 1.671e+00, train_acc 37.4, test_acc 31.5
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 9000, dt 0.62s, train_loss 1.534e+00, test_loss 1.671e+00, train_acc 37.4, test_acc 31.5
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 10000, dt 0.62s, train_loss 1.534e+00, test_loss 1.672e+00, train_acc 37.5, test_acc 31.5
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# 0.009000000000000001
# step 11000, dt 0.63s, train_loss 1.534e+00, test_loss 1.672e+00, train_acc 37.4, test_acc 31.5
# Epoch    46: reducing learning rate of group 0 to 8.1000e-03.
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 12000, dt 0.62s, train_loss 1.533e+00, test_loss 1.670e+00, train_acc 37.9, test_acc 31.5
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 13000, dt 0.59s, train_loss 1.534e+00, test_loss 1.670e+00, train_acc 38.0, test_acc 31.5
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 14000, dt 0.62s, train_loss 1.534e+00, test_loss 1.670e+00, train_acc 38.0, test_acc 31.5
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 15000, dt 0.57s, train_loss 1.534e+00, test_loss 1.670e+00, train_acc 37.9, test_acc 31.5
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.008100000000000001
# step 16000, dt 0.60s, train_loss 1.534e+00, test_loss 1.670e+00, train_acc 37.9, test_acc 31.5
# 0.008100000000000001
# Epoch    67: reducing learning rate of group 0 to 7.2900e-03.
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 17000, dt 0.63s, train_loss 1.535e+00, test_loss 1.669e+00, train_acc 37.9, test_acc 31.3
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 18000, dt 0.63s, train_loss 1.535e+00, test_loss 1.669e+00, train_acc 37.8, test_acc 31.3
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 19000, dt 0.63s, train_loss 1.535e+00, test_loss 1.669e+00, train_acc 37.8, test_acc 31.2
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.007290000000000001
# step 20000, dt 0.60s, train_loss 1.535e+00, test_loss 1.669e+00, train_acc 37.8, test_acc 31.2

# %%
fig = plt.figure(figsize=(4.1, 3), dpi=150)

plt.subplot(1,1,1)
t = range(0, args.total_steps+1, args.eval_every)
plt.plot(t, results_lin['test_acc'], 'r-', label='logistic')
plt.plot(t, results_mlp['test_acc'], 'g-', label='mlp')
plt.plot(t, results_cnn['test_acc'], 'b-', label='cnn')
plt.plot(t, results_gru['test_acc'], 'c-', label='gru')

plt.plot(t, [95.8]*len(t), 'k-', label='human')

plt.title('Test accuracy') ; plt.xlabel("Train step") ; plt.legend(fontsize=6.5, ncol=5, loc='lower right')
plt.xticks(fontsize=9) ; plt.yticks(fontsize=9)
plt.ylim(0,105)
plt.tight_layout() ; plt.show()

# %% [markdown]
# ## Step 5: Conclusions
# We believe this dataset is ideal for performing small-scale, "science of deep learning" experiments.
#
# Try it out, do something interesting, and share it with us via a Colab. We would like to feature your work in our README.
